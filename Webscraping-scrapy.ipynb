# %% [markdown]
# ### Webscraping

# %% [markdown]
# ##### What is Beautiful Soup?
# Simple but powerful or simply powerful, Beautiful Soup is a Python parsing library that can get data from HTML, XML, and other markup languages. If you're just starting out and want to learn how to use Beautiful Soup, you'll find it to be a very beginner-friendly option for parsing web content. It uses tags, text content, and attributes as search criteria which makes navigating and searching the HTML tree much easier. Put simply, it’s a tool that helps you pull structured data from web pages. If you're new to using Beautiful Soup or want a refresher on how it works in practice, check out our BeautifulSoup Tutorial – How to Parse Web Data With Python.

# %% [markdown]
# ##### Main features
# - Dealing with poorly formatted HTML
#
#     In most situations, Beautiful Soup will help you parse data even from the most ill-formatted HTMLs. Of course, for the most extreme cases you might need to play around with Beautiful Soup’s parameters.
#
# - Encoding conversion
#
#     Beautiful Soup has the capability of automatically detecting the document encoding method and converting it to a suitable format. In case it doesn’t, you can still specify it and get the job done.
#
# - Integration with parsing libraries
#
#     Sitting on top of such parsing libraries as lxml and html5lib, Beautiful Soup can give your parsing approaches much more flexibility.
#
# - Excellent error handling
#
#     Beautiful Soup handles parsing mistakes by giving you thorough error messages and facilitating easier parsing error recovery. As a result, the parsing process becomes much more manageable.

# %% [markdown]
# ##### Advantages of using Beautiful Soup
# - Beginner friendly
# - Open-source and free
# - Simple to implement
# - Flexible parsing options
#
# ##### Disadvantages of using Beautiful Soup
# - Many dependencies
# - Not very scalable
# - Minimal proxy support

# %% [markdown]
# #### What is Scrapy?
# Scrapy is an open-source application framework that has traditionally been used to crawl and extract data. It’s a stand-alone tool, which means that you can take it as it is and put it to work. However, Scrapy web scraping is not the only approach to take as this tool can also be used for data mining and automated testing.
#
# ##### Main features
# - Asynchronous request handling
#
# Scrapy is able to handle and prioritize multiple requests, making large-scale scraping operations easier, faster, and more efficient.
#
# - Middlewares and extensions
#
# Being a framework dedicated to web scraping, Scrapy offers a number of middleware and extensions to support various web scraping processes. As such, it skillfully handles such things as cookies, redirects, forms, and pagination.
#
# - Spider framework
#
# There are many ways to scrape a website and that’s why Scrapy allows users to specify their preferred approach. By using Scrapy’s spider framework, users can define the exact way that they want a website (or a batch of them) to be crawled, scraped, and parsed.
#
# - AutoThrottling
#
# You can configure Scrapy so it doesn’t exhaust the target server's resources. The AutoThrottle extension evaluates the load on the Scrapy server as well as the target website server and adjusts the crawling speed.
#
# ##### Advantages of using Scrapy
# - Easy-to-follow documentation
# - Doesn’t require other dependencies (unless working with JavaScript)
# - Can be used for large-scale scraping
# - Memory-efficient structure (check out this Scrapy and AWS Lambda tutorial for a serverless Scrapy solution)
#
# ##### Disadvantages of using Scrapy
# - Cannot handle JavaScript
# - Steep learning curve

# %% [markdown]
# Scrapy is a Python web scraping framework built around Twisted, an asynchronous networking engine. This means that it doesn't use the standard asynchronous Python approach. Instead, it uses an event-driven networking infrastructure, allowing for more efficiency and scalability.
#
# That being said, we don't have to interact with the underlying architecture. Scrapy abstracts it away with its own interface. From the development perspective, we'll mostly deal with the equivalent logic in callbacks and generators

# %% [markdown]
# ![scrapy](scrapy-spider.svg)

# %% [markdown]
# The above illustration explains the Scrapy architecture in simple terms. Scrapy comes with an engine called Crawler (light blue). It handles the low-level logic, such as the HTTP connection, scheduling and the entire execution flow.
#
# On the other hand, the high-level logic (dark blue) is missing. It's called Spider, which handles the scraping logic and how to perform it. In simple terms, we must provide the Crawler with a Spider object to generate the requests, parse and retrieve the data to store

# %% [markdown]
# Now before we create our first Spider to web scrape with Scrapy. Let's start off by defining common Scrapy terms:
#
# - Callback
#
# Scrapy is an asyncronous framework. Therefore, most of the actions are executed in the background, which allows for highly concurrent and efficient logic. In this context, a callback is a function that's attached to a background task, which called upon the successful finish of this task.
#
# - Errorback
#
# A similar function to the callback, but it is triggered when a task fails instead of when it succeeds.
#
# - Generator
#
# In Python, generators are functions that return results one at a time instead of all at once like a list.
#
# - Settings
#
# Scrapy's central configuration object, called settings and it's located in the settings.py file of the project.

# %% [markdown]
# |Criteria|	Scrapy|	Beautiful Soup|
# |--------|-----------|-------|
# |Purpose|	Web scraping and crawling|	Parsing|
# |Speed	|Fast	|Average|
# |Scraping projects	|Small to large scale	|Small to medium scale|
# |Scalability	Highly scalable and can handle large-scale projects	|Not as suitable for large-scale projects|
# |Asynchronous	|Yes	|No|
# |Crawling	|Designed for web scraping and crawling	|Focused on parsing and manipulating HTML|
# |Extensions	|High	|Limited|
# |Browser support	|No	|Chrome, Edge, Firefox, and Safari|
# |Headless execution|	No	|Yes|
# |Browser interaction|	No|	Yes|

# %%
# !pip install scrapy bs4

# %%
import scrapy

# %% [markdown]
# ### Step 1: Create a Scrapy Project

# %%
# !scrapy startproject bookscraper
# !cd bookscraper
# Out:
# Error: scrapy.cfg already exists in C:\Users\sadiq\OneDrive\Desktop\GUVI\bookscraper

# %% [markdown]
# This creates a structured project with folders for spiders, pipelines, settings, etc.

# %% [markdown]
# ### Step 2: Step 2: Create a Spider

# %% [markdown]
# Navigate to bookscraper/spiders/ and create a file called book_spider.py

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sadiq\\OneDrive\\Desktop\\GUVI'

# %%
# %%writefile "./bookscraper/bookscraper/spiders/book_spider.py"
#
# import scrapy
#
# class BookSpider(scrapy.Spider):
#     name = "books"
#     start_urls = ['http://books.toscrape.com/']
#
#     def parse(self, response):
#         for book in response.css('article.product_pod'):
#             yield {
#                 'title': book.css('h3 a::attr(title)').get(),
#                 'price': book.css('.price_color::text').get()
#             }
#
#         # Follow pagination links
#         next_page = response.css('li.next a::attr(href)').get()
#         if next_page:
#             yield response.follow(next_page, self.parse)
# Out:
# Overwriting ./bookscraper/bookscraper/spiders/book_spider.py

# %% [markdown]
# ### Step 3: Run the Spider

# %%
import os
from scrapy.cmdline import execute

os.chdir('./bookscraper')  # Must contain scrapy.cfg
execute(['scrapy', 'crawl', 'books', '-o', 'books.json'])
# Out:
# 2025-09-17 13:30:40 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: bookscraper)
# 2025-09-17 13:30:40 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.1',
#  'libxml2': '2.11.9',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.11.13 | packaged by Anaconda, Inc. | (main, Jun  5 2025, '
#            '13:03:15) [MSC v.1929 64 bit (AMD64)]',
#  'pyOpenSSL': '25.1.0 (OpenSSL 3.5.2 5 Aug 2025)',
#  'cryptography': '45.0.7',
#  'Platform': 'Windows-10-10.0.26100-SP0'}
# 2025-09-17 13:30:40 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-09-17 13:30:40 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-09-17 13:30:40 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2025-09-17 13:30:40 [scrapy.extensions.telnet] INFO: Telnet Password: 88864597e51032cb
# 2025-09-17 13:30:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-09-17 13:30:40 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'bookscraper',
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 1,
#  'DOWNLOAD_DELAY': 1,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'bookscraper.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['bookscraper.spiders']}
# 2025-09-17 13:30:40 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-09-17 13:30:40 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-09-17 13:30:40 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 5
#       2 from scrapy.cmdline import execute
#       4 os.chdir('./bookscraper')  # Must contain scrapy.cfg
# ----> 5 execute(['scrapy', 'crawl', 'books', '-o', 'books.json'])
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\cmdline.py:205, in execute(argv, settings)
#     202 _run_print_help(parser, cmd.process_options, args, opts)
#     204 cmd.crawler_process = CrawlerProcess(settings)
# --> 205 _run_print_help(parser, _run_command, cmd, args, opts)
#     206 sys.exit(cmd.exitcode)
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\cmdline.py:158, in _run_print_help(parser, func, *a, **kw)
#     151 def _run_print_help(
#     152     parser: argparse.ArgumentParser,
#     153     func: Callable[_P, None],
#     154     *a: _P.args,
#     155     **kw: _P.kwargs,
#     156 ) -> None:
#     157     try:
# --> 158         func(*a, **kw)
#     159     except UsageError as e:
#     160         if str(e):
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\cmdline.py:213, in _run_command(cmd, args, opts)
#     211     _run_command_profiled(cmd, args, opts)
#     212 else:
# --> 213     cmd.run(args, opts)
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\commands\crawl.py:40, in Command.run(self, args, opts)
#      38     self.exitcode = 1
#      39 else:
# ---> 40     self.crawler_process.start()
#      42     if self.crawler_process.bootstrap_failed or (
#      43         hasattr(self.crawler_process, "has_exception")
#      44         and self.crawler_process.has_exception
#      45     ):
#      46         self.exitcode = 1
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\crawler.py:502, in CrawlerProcess.start(self, stop_after_crawl, install_signal_handlers)
#     498 if install_signal_handlers:
#     499     reactor.addSystemEventTrigger(
#     500         "after", "startup", install_shutdown_handlers, self._signal_shutdown
#     501     )
# --> 502 reactor.run(installSignalHandlers=install_signal_handlers)
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\twisted\internet\asyncioreactor.py:253, in AsyncioSelectorReactor.run(self, installSignalHandlers)
#     251 def run(self, installSignalHandlers=True):
#     252     self.startRunning(installSignalHandlers=installSignalHandlers)
# --> 253     self._asyncioEventloop.run_forever()
#     254     if self._justStopped:
#     255         self._justStopped = False
#
# File ~\anaconda3\envs\guvi\Lib\asyncio\base_events.py:597, in BaseEventLoop.run_forever(self)
#     595 """Run until stop() is called."""
#     596 self._check_closed()
# --> 597 self._check_running()
#     598 self._set_coroutine_origin_tracking(self._debug)
#     600 old_agen_hooks = sys.get_asyncgen_hooks()
#
# File ~\anaconda3\envs\guvi\Lib\asyncio\base_events.py:589, in BaseEventLoop._check_running(self)
#     587 def _check_running(self):
#     588     if self.is_running():
# --> 589         raise RuntimeError('This event loop is already running')
#     590     if events._get_running_loop() is not None:
#     591         raise RuntimeError(
#     592             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
# 2025-09-17 13:30:41 [scrapy.core.engine] INFO: Spider opened
# 2025-09-17 13:30:41 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-09-17 13:30:41 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-09-17 13:30:42 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://books.toscrape.com/robots.txt> (referer: None)
# 2025-09-17 13:30:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/> (referer: None)
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'A Light in the Attic', 'price': '£51.77'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Tipping the Velvet', 'price': '£53.74'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Soumission', 'price': '£50.10'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Sharp Objects', 'price': '£47.82'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Sapiens: A Brief History of Humankind', 'price': '£54.23'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Requiem Red', 'price': '£22.65'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price': '£33.34'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'price': '£17.93'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price': '£22.60'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Black Maria', 'price': '£52.15'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'price': '£13.99'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "Shakespeare's Sonnets", 'price': '£20.66'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Set Me Free', 'price': '£17.46'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'price': '£52.29'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Rip it Up and Start Again', 'price': '£35.02'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'price': '£57.25'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Olio', 'price': '£23.88'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'price': '£37.59'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Libertarianism for Beginners', 'price': '£51.33'}
# 2025-09-17 13:30:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "It's Only the Himalayas", 'price': '£45.17'}
# 2025-09-17 13:30:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-2.html> (referer: http://books.toscrape.com/)
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'In Her Wake', 'price': '£12.84'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'How Music Works', 'price': '£37.32'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'price': '£30.52'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Chase Me (Paris Nights #2)', 'price': '£25.27'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Black Dust', 'price': '£34.53'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Birdsong: A Story in Pictures', 'price': '£54.64'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'price': '£22.50'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Aladdin and His Wonderful Lamp', 'price': '£53.13'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 'price': '£40.30'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Wall and Piece', 'price': '£44.18'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'price': '£17.66'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'price': '£31.05'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Elephant Tree', 'price': '£23.82'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Bear and the Piano', 'price': '£36.89'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "Sophie's World", 'price': '£15.94'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Penny Maybe', 'price': '£33.29'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Maude (1883-1993):She Grew Up with the country', 'price': '£18.02'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'In a Dark, Dark Wood', 'price': '£19.63'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Behind Closed Doors', 'price': '£52.22'}
# 2025-09-17 13:30:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "You can't bury them all: Poems", 'price': '£33.63'}
# 2025-09-17 13:30:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-3.html> (referer: http://books.toscrape.com/catalogue/page-2.html)
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Slow States of Collapse: Poems', 'price': '£57.31'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Reasons to Stay Alive', 'price': '£26.41'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Private Paris (Private #10)', 'price': '£47.61'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'price': '£23.11'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Without Borders (Wanderlove #1)', 'price': '£45.07'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'When We Collided', 'price': '£31.77'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'We Love You, Charlie Freeman', 'price': '£50.27'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Untitled Collection: Sabbath Poems 2014', 'price': '£14.27'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 'price': '£44.18'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unicorn Tracks', 'price': '£18.78'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', 'price': '£25.52'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 'price': '£16.28'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity', 'price': '£31.12'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'This One Summer', 'price': '£19.49'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Thirst', 'price': '£17.27'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Torch Is Passed: A Harding Family Story', 'price': '£19.09'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Secret of Dreadwillow Carse', 'price': '£56.13'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 'price': '£56.41'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Past Never Ends', 'price': '£56.50'}
# 2025-09-17 13:30:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Natural History of Us (The Fine Art of Pretending #2)', 'price': '£45.22'}
# 2025-09-17 13:30:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-4.html> (referer: http://books.toscrape.com/catalogue/page-3.html)
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Nameless City (The Nameless City #1)', 'price': '£38.16'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Murder That Never Was (Forensic Instincts #5)', 'price': '£54.11'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 'price': '£42.96'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', 'price': '£23.89'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing', 'price': '£16.77'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 'price': '£20.59'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure', 'price': '£37.13'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3', 'price': '£56.06'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Death of Humanity: and the Case for Life', 'price': '£58.11'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 'price': '£49.05'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Art Forger', 'price': '£40.76'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', 'price': '£19.73'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 'price': '£32.24'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 'price': '£41.83'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Soul Reader', 'price': '£39.58'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Security', 'price': '£39.25'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)', 'price': '£25.02'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)', 'price': '£51.04'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Reskilling America: Learning to Labor in the Twenty-First Century', 'price': '£19.83'}
# 2025-09-17 13:30:46 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', 'price': '£50.40'}
# 2025-09-17 13:30:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-5.html> (referer: http://books.toscrape.com/catalogue/page-4.html)
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 'price': '£13.61'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Princess Between Worlds (Wide-Awake Princess #5)', 'price': '£13.34'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Pop Gun War, Volume 1: Gift', 'price': '£18.97'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 'price': '£36.28'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Patience', 'price': '£10.16'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 'price': '£15.44'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)', 'price': '£48.41'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide', 'price': '£46.35'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'On a Midnight Clear', 'price': '£14.07'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Obsidian (Lux #1)', 'price': '£14.86'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'My Paris Kitchen: Recipes and Stories', 'price': '£33.37'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Masks and Shadows', 'price': '£56.40'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 'price': '£14.02'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 'price': '£46.91'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', 'price': '£45.61'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 'price': '£19.92'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Layered: Baking, Building, and Styling Spectacular Cakes', 'price': '£40.11'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 'price': '£53.90'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Join', 'price': '£35.67'}
# 2025-09-17 13:30:47 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'In the Country We Love: My Family Divided', 'price': '£22.00'}
# 2025-09-17 13:30:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-6.html> (referer: http://books.toscrape.com/catalogue/page-5.html)
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 'price': '£57.36'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)', 'price': '£29.17'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'I am a Hero Omnibus Volume 1', 'price': '£54.63'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'How to Be Miserable: 40 Strategies You Already Use', 'price': '£46.03'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Her Backup Boyfriend (The Sorensen Family #1)', 'price': '£33.97'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Giant Days, Vol. 2 (Giant Days #5-8)', 'price': '£22.11'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton', 'price': '£29.69'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'First and First (Five Boroughs #3)', 'price': '£15.97'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Fifty Shades Darker (Fifty Shades #2)', 'price': '£21.96'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day', 'price': '£54.35'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", 'price': '£37.97'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Danganronpa Volume 1', 'price': '£51.99'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Crown of Midnight (Throne of Glass #2)', 'price': '£43.29'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Codename Baboushka, Volume 1: The Conclave of Death', 'price': '£36.72'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Camp Midnight', 'price': '£17.08'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 'price': '£29.14'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Burning', 'price': '£28.81'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Bossypants', 'price': '£49.46'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))', 'price': '£37.92'}
# 2025-09-17 13:30:49 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)', 'price': '£28.09'}
# 2025-09-17 13:30:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-7.html> (referer: http://books.toscrape.com/catalogue/page-6.html)
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Algorithms to Live By: The Computer Science of Human Decisions', 'price': '£30.81'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A World of Flavor: Your Gluten Free Passport', 'price': '£42.95'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 'price': '£56.76'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Murder in Time', 'price': '£16.64'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Flight of Arrows (The Pathfinders #2)', 'price': '£55.53'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Fierce and Subtle Poison', 'price': '£28.13'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)', 'price': '£52.37'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': '(Un)Qualified: How God Uses Broken People to Do Big Things', 'price': '£54.00'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'You Are What You Love: The Spiritual Power of Habit', 'price': '£21.87'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", 'price': '£43.30'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Tuesday Nights in 1980', 'price': '£21.04'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Tracing Numbers on a Train', 'price': '£41.60'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Throne of Glass (Throne of Glass #1)', 'price': '£35.07'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', 'price': '£59.64'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Thirteen Reasons Why', 'price': '£52.72'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”', 'price': '£58.08'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Wedding Dress', 'price': '£24.12'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Vacationers', 'price': '£42.15'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Third Wave: An Entrepreneur’s Vision of the Future', 'price': '£12.61'}
# 2025-09-17 13:30:50 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Stranger', 'price': '£17.44'}
# 2025-09-17 13:30:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-8.html> (referer: http://books.toscrape.com/catalogue/page-7.html)
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Shadow Hero (The Shadow Hero)', 'price': '£33.14'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Secret (The Secret #1)', 'price': '£27.37'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Regional Office Is Under Attack!', 'price': '£51.36'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Psychopath Test: A Journey Through the Madness Industry', 'price': '£36.00'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Project', 'price': '£10.65'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Power of Now: A Guide to Spiritual Enlightenment', 'price': '£43.54'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': "The Omnivore's Dilemma: A Natural History of Four Meals", 'price': '£38.21'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 'price': '£37.34'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 'price': '£44.10'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Mistake (Off-Campus #2)', 'price': '£43.29'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': "The Matchmaker's Playbook (Wingmen Inc. #1)", 'price': '£55.85'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking', 'price': '£37.60'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City', 'price': '£10.97'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Kite Runner', 'price': '£41.82'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The House by the Lake', 'price': '£36.95'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Glittering Court (The Glittering Court #1)', 'price': '£44.28'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Girl on the Train', 'price': '£55.02'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Genius of Birds', 'price': '£17.24'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Emerald Mystery', 'price': '£23.15'}
# 2025-09-17 13:30:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-8.html>
# {'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First', 'price': '£41.25'}
# 2025-09-17 13:30:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-9.html> (referer: http://books.toscrape.com/catalogue/page-8.html)
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.", 'price': '£32.00'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': "The Artist's Way: A Spiritual Path to Higher Creativity", 'price': '£38.49'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'The Art of War', 'price': '£33.34'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'The Argonauts', 'price': '£10.93'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job', 'price': '£27.55'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Suddenly in Love (Lake Haven #1)', 'price': '£55.99'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Something More Than This', 'price': '£16.24'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Soft Apocalypse', 'price': '£26.12'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': "So You've Been Publicly Shamed", 'price': '£12.23'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Shoe Dog: A Memoir by the Creator of NIKE', 'price': '£23.99'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Shobu Samurai, Project Aryoku (#3)', 'price': '£29.06'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Secrets and Lace (Fatal Hearts #1)', 'price': '£20.27'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Scarlett Epstein Hates It Here', 'price': '£43.55'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Romero and Juliet: A Tragic Tale of Love and Zombies', 'price': '£36.94'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Redeeming Love', 'price': '£20.47'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form', 'price': '£41.06'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Poems That Make Grown Women Cry', 'price': '£14.19'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Nightingale, Sing', 'price': '£38.28'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Night Sky with Exit Wounds', 'price': '£41.05'}
# 2025-09-17 13:30:53 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-9.html>
# {'title': 'Mrs. Houdini', 'price': '£30.25'}
# 2025-09-17 13:30:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-10.html> (referer: http://books.toscrape.com/catalogue/page-9.html)
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Modern Romance', 'price': '£28.26'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)', 'price': '£10.76'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Louisa: The Extraordinary Life of Mrs. Adams', 'price': '£16.85'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Little Red', 'price': '£13.47'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Library of Souls (Miss Peregrine’s Peculiar Children #3)', 'price': '£48.56'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Large Print Heart of the Pride', 'price': '£19.15'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 'price': '£57.36'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Hollow City (Miss Peregrine’s Peculiar Children #2)', 'price': '£42.98'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Grumbles', 'price': '£22.16'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond', 'price': '£49.43'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Frostbite (Vampire Academy #2)', 'price': '£29.99'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Follow You Home', 'price': '£21.36'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'First Steps for New Christians (Print Edition)', 'price': '£29.00'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Finders Keepers (Bill Hodges Trilogy #2)', 'price': '£53.53'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Fables, Vol. 1: Legends in Exile (Fables #1)', 'price': '£41.62'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Eureka Trivia 6.0', 'price': '£54.59'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Drive: The Surprising Truth About What Motivates Us', 'price': '£34.95'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Done Rubbed Out (Reightman & Bailey #1)', 'price': '£37.72'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Doing It Over (Most Likely To #1)', 'price': '£35.61'}
# 2025-09-17 13:30:55 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-10.html>
# {'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals', 'price': '£42.16'}
# 2025-09-17 13:30:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-11.html> (referer: http://books.toscrape.com/catalogue/page-10.html)
# 2025-09-17 13:30:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'title': 'Dark Notes', 'price': '£19.19'}
# 2025-09-17 13:30:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'title': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead', 'price': '£19.43'}
# 2025-09-17 13:30:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'title': 'Close to You', 'price': '£49.46'}
# 2025-09-17 13:30:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'title': 'Chasing Heaven: What Dying Taught Me About Living', 'price': '£37.80'}
# 2025-09-17 13:30:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'title': 'Big Magic: Creative Living Beyond Fear', 'price': '£30.80'}
# 2025-09-17 13:30:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'title': 'Becoming Wise: An Inquiry into the Mystery and Art of Living', 'price': '£27.43'}
# 2025-09-17 13:30:56 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-11.html>
# {'title': 'Beauty Restored (Riley Family Legacy Novellas #3)', 'price': '£11.11'}
# ...
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Republic', 'price': '£33.78'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Odyssey', 'price': '£29.64'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", 'price': '£57.70'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Nicomachean Ethics', 'price': '£36.34'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Name of the Wind (The Kingkiller Chronicle #1)', 'price': '£50.59'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)', 'price': '£29.38'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Little Prince', 'price': '£45.42'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Light of the Fireflies', 'price': '£54.43'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Last Girl (The Dominion Trilogy #1)', 'price': '£36.26'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Iliad', 'price': '£16.16'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Hook Up (Game On #1)', 'price': '£36.29'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Haters', 'price': '£27.89'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Girl You Lost', 'price': '£12.29'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Girl In The Ice (DCI Erika Foster #1)', 'price': '£15.85'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The End of the Jesus Era (An Investigation #1)', 'price': '£14.40'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Edge of Reason (Bridget Jones #2)', 'price': '£19.18'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Complete Maus (Maus #1-2)', 'price': '£10.64'}
# 2025-09-17 13:32:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-47.html>
# {'title': 'The Communist Manifesto', 'price': '£14.76'}
# 2025-09-17 13:32:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-48.html> (referer: http://books.toscrape.com/catalogue/page-47.html)
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'The Bhagavad Gita', 'price': '£57.49'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'The Bette Davis Club', 'price': '£30.66'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'The Art of Not Breathing', 'price': '£40.83'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Taking Shots (Assassins #1)', 'price': '£18.88'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Starlark', 'price': '£25.83'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Skip Beat!, Vol. 01 (Skip Beat! #1)', 'price': '£42.12'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Sister Sable (The Mad Queen #1)', 'price': '£13.33'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Shatter Me (Shatter Me #1)', 'price': '£42.40'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Shameless', 'price': '£58.35'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Shadow Rites (Jane Yellowrock #10)', 'price': '£21.72'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Settling the Score (The Summer Games #1)', 'price': '£44.91'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Sense and Sensibility', 'price': '£37.46'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Saga, Volume 1 (Saga (Collected Editions) #1)', 'price': '£28.48'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Rhythm, Chord & Malykhin', 'price': '£28.34'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)', 'price': '£46.96'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Paradise Lost (Paradise #1)', 'price': '£24.96'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)', 'price': '£21.71'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)', 'price': '£29.87'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'Origins (Alphas 0.5)', 'price': '£28.99'}
# 2025-09-17 13:32:11 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-48.html>
# {'title': 'One Second (Seven #7)', 'price': '£52.94'}
# 2025-09-17 13:32:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-49.html> (referer: http://books.toscrape.com/catalogue/page-48.html)
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'On the Road (Duluoz Legend)', 'price': '£32.36'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': "Old Records Never Die: One Man's Quest for His Vinyl and His Past", 'price': '£55.66'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Off Sides (Off #1)', 'price': '£39.45'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Of Mice and Men', 'price': '£47.11'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Myriad (Prentor #1)', 'price': '£58.75'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'My Perfect Mistake (Over the Top #1)', 'price': '£38.92'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', 'price': '£39.39'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Meditations', 'price': '£25.89'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Matilda', 'price': '£28.34'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Lost Among the Living', 'price': '£27.70'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Lord of the Flies', 'price': '£24.89'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Listen to Me (Fusion #1)', 'price': '£58.99'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Kitchens of the Great Midwest', 'price': '£57.20'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Jane Eyre', 'price': '£38.43'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Imperfect Harmony', 'price': '£34.74'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Icing (Aces Hockey #2)', 'price': '£40.44'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)', 'price': '£45.24'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", 'price': '£34.96'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Giant Days, Vol. 1 (Giant Days #1-4)', 'price': '£56.76'}
# 2025-09-17 13:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-49.html>
# {'title': 'Fruits Basket, Vol. 1 (Fruits Basket #1)', 'price': '£40.28'}
# 2025-09-17 13:32:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-50.html> (referer: http://books.toscrape.com/catalogue/page-49.html)
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Frankenstein', 'price': '£38.00'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Forever Rockers (The Rocker #12)', 'price': '£28.80'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Fighting Fate (Fighting #6)', 'price': '£39.24'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Emma', 'price': '£32.93'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Eat, Pray, Love', 'price': '£51.32'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Deep Under (Walker Security #1)', 'price': '£47.09'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': "Choosing Our Religion: The Spiritual Lives of America's Nones", 'price': '£28.42'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)', 'price': '£22.85'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': "Charity's Cross (Charles Towne Belles #4)", 'price': '£41.24'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Bright Lines', 'price': '£39.07'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': "Bridget Jones's Diary (Bridget Jones #1)", 'price': '£29.82'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Bounty (Colorado Mountain #7)', 'price': '£37.26'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Blood Defense (Samantha Brinkman #1)', 'price': '£20.30'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', 'price': '£34.65'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Beyond Good and Evil', 'price': '£43.38'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': "Alice in Wonderland (Alice's Adventures in Wonderland #1)", 'price': '£55.53'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', 'price': '£57.06'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': "A Spy's Devotion (The Regency Spies of London #1)", 'price': '£16.97'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': "1st to Die (Women's Murder Club #1)", 'price': '£53.98'}
# 2025-09-17 13:32:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-50.html>
# {'title': '1,000 Places to See Before You Die', 'price': '£26.08'}
# 2025-09-17 13:32:14 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-09-17 13:32:14 [scrapy.extensions.feedexport] INFO: Stored json feed (1000 items) in: books.json
# 2025-09-17 13:32:14 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 15110,
#  'downloader/request_count': 51,
#  'downloader/request_method_count/GET': 51,
#  'downloader/response_bytes': 2552973,
#  'downloader/response_count': 51,
#  'downloader/response_status_count/200': 50,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 93.279637,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 9, 17, 8, 2, 14, 758670, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 1000,
#  'items_per_minute': 645.1612903225806,
#  'log_count/DEBUG': 1053,
#  'log_count/INFO': 12,
#  'request_depth_max': 49,
#  'response_received_count': 51,
#  'responses_per_minute': 32.90322580645161,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 50,
#  'scheduler/dequeued/memory': 50,
#  'scheduler/enqueued': 50,
#  'scheduler/enqueued/memory': 50,
#  'start_time': datetime.datetime(2025, 9, 17, 8, 0, 41, 479033, tzinfo=datetime.timezone.utc)}
# 2025-09-17 13:32:14 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# This crawls all pages and saves book titles and prices to books.json.

# %% [markdown]
# ### How to write crawling logic

# %% [markdown]
# ##### 1. Start Points (start_urls or start_requests)
#
# - Define where your crawl begins.
# - Use static URLs or dynamically generate them from a database, sitemap, or API.

# %%
class MySpider(scrapy.Spider):
    name = "example"
    start_urls = ['https://example.com']

    def parse(self, response):
        ...

# %% [markdown]
# For large-scale or multi-domain crawls, use start_requests() to yield requests dynamically.

# %% [markdown]
# ##### 2.  Link Following Strategy
# - Decide whether to follow links recursively.
# - Use response.follow() or response.css('a::attr(href)') to extract and follow links.

# %%
def parse(self, response):
    for href in response.css('a::attr(href)').getall():
        yield response.follow(href, self.parse)

# %% [markdown]
# You can limit depth using DEPTH_LIMIT in settings.py.

# %% [markdown]
# ##### 3. Domain Scope (allowed_domains)
# - Restrict crawling to specific domains to avoid going off-target.
# allowed_domains = ['example.com']

# %% [markdown]
# ##### 4. Data Extraction Logic
# - Use CSS or XPath selectors to extract structured data.
# - Keep selectors clean and test them in scrapy shell.

# %%
yield {
    'title': response.css('h1::text').get(),
    'price': response.css('.price::text').get()
}

# %% [markdown]
# ##### 5. Pagination Handling
# - Detect and follow “next page” links.

# %%
next_page = response.css('li.next a::attr(href)').get()
if next_page:
    yield response.follow(next_page, self.parse)

# %% [markdown]
# ##### 6. Broad vs Focused Crawl
# - Focused Crawl: Deep crawl of a single domain.
# - Broad Crawl: Shallow crawl across many domains, often time-limited.
# -
# For broad crawls:
# - Use Breadth-First Order to reduce memory usage.
# - Tune concurrency (CONCURRENT_REQUESTS) and DNS resolution settings.

# %% [markdown]
# ##### Debugging and Refining Logic
# - Use scrapy shell to test selectors and response structure.
# - Use scrapy check to validate spider syntax.
# - Log URLs and items to verify crawl paths.

# %%
import scrapy
from urllib.parse import urlparse

class DualDomainSpider(scrapy.Spider):
    name = "dual"
    allowed_domains = ["quotes.toscrape.com", "books.toscrape.com"]
    start_urls = [
        "http://quotes.toscrape.com/page/1/",
        "http://books.toscrape.com/catalogue/page-1.html"
    ]

    custom_settings = {
        'FEEDS': {
            'output.json': {
                'format': 'json',
                'encoding': 'utf8',
                'indent': 4,
            }
        },
        'DOWNLOAD_DELAY': 1,
        'DEPTH_LIMIT': 2,
        'AUTOTHROTTLE_ENABLED': True,
        'AUTOTHROTTLE_START_DELAY': 1,
        'AUTOTHROTTLE_MAX_DELAY': 3,
    }

    def parse(self, response):
        domain = urlparse(response.url).netloc

        if "quotes.toscrape.com" in domain:
            for quote in response.css("div.quote"):
                yield {
                    "domain": domain,
                    "type": "quote",
                    "text": quote.css("span.text::text").get(),
                    "author": quote.css("small.author::text").get(),
                    "tags": quote.css("div.tags a.tag::text").getall()
                }

            next_page = response.css("li.next a::attr(href)").get()
            if next_page:
                yield response.follow(next_page, self.parse)

        elif "books.toscrape.com" in domain:
            for book in response.css("article.product_pod"):
                yield {
                    "domain": domain,
                    "type": "book",
                    "title": book.css("h3 a::attr(title)").get(),
                    "price": book.css(".price_color::text").get()
                }

            next_page = response.css("li.next a::attr(href)").get()
            if next_page:
                yield response.follow(next_page, self.parse)

# %%
LOG_LEVEL = 'INFO'

# %%
import os
from scrapy.cmdline import execute
os.chdir('./bookscraper')
execute(['scrapy', 'crawl', 'books', '-o', 'books.json'])
# Out:
# 2025-09-17 14:10:15 [scrapy.utils.log] INFO: Scrapy 2.13.3 started (bot: bookscraper)
# 2025-09-17 14:10:16 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.0.1',
#  'libxml2': '2.11.9',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '25.5.0',
#  'Python': '3.11.13 | packaged by Anaconda, Inc. | (main, Jun  5 2025, '
#            '13:03:15) [MSC v.1929 64 bit (AMD64)]',
#  'pyOpenSSL': '25.1.0 (OpenSSL 3.5.2 5 Aug 2025)',
#  'cryptography': '45.0.7',
#  'Platform': 'Windows-10-10.0.26100-SP0'}
# 2025-09-17 14:10:16 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-09-17 14:10:16 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-09-17 14:10:16 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2025-09-17 14:10:16 [scrapy.extensions.telnet] INFO: Telnet Password: be0dcf71dc82c87e
# 2025-09-17 14:10:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-09-17 14:10:16 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'bookscraper',
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 1,
#  'DOWNLOAD_DELAY': 1,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'bookscraper.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['bookscraper.spiders']}
# 2025-09-17 14:10:16 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-09-17 14:10:16 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-09-17 14:10:16 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 4
#       2 from scrapy.cmdline import execute
#       3 os.chdir('./bookscraper')
# ----> 4 execute(['scrapy', 'crawl', 'books', '-o', 'books.json'])
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\cmdline.py:205, in execute(argv, settings)
#     202 _run_print_help(parser, cmd.process_options, args, opts)
#     204 cmd.crawler_process = CrawlerProcess(settings)
# --> 205 _run_print_help(parser, _run_command, cmd, args, opts)
#     206 sys.exit(cmd.exitcode)
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\cmdline.py:158, in _run_print_help(parser, func, *a, **kw)
#     151 def _run_print_help(
#     152     parser: argparse.ArgumentParser,
#     153     func: Callable[_P, None],
#     154     *a: _P.args,
#     155     **kw: _P.kwargs,
#     156 ) -> None:
#     157     try:
# --> 158         func(*a, **kw)
#     159     except UsageError as e:
#     160         if str(e):
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\cmdline.py:213, in _run_command(cmd, args, opts)
#     211     _run_command_profiled(cmd, args, opts)
#     212 else:
# --> 213     cmd.run(args, opts)
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\commands\crawl.py:40, in Command.run(self, args, opts)
#      38     self.exitcode = 1
#      39 else:
# ---> 40     self.crawler_process.start()
#      42     if self.crawler_process.bootstrap_failed or (
#      43         hasattr(self.crawler_process, "has_exception")
#      44         and self.crawler_process.has_exception
#      45     ):
#      46         self.exitcode = 1
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\scrapy\crawler.py:502, in CrawlerProcess.start(self, stop_after_crawl, install_signal_handlers)
#     498 if install_signal_handlers:
#     499     reactor.addSystemEventTrigger(
#     500         "after", "startup", install_shutdown_handlers, self._signal_shutdown
#     501     )
# --> 502 reactor.run(installSignalHandlers=install_signal_handlers)
#
# File ~\anaconda3\envs\guvi\Lib\site-packages\twisted\internet\asyncioreactor.py:253, in AsyncioSelectorReactor.run(self, installSignalHandlers)
#     251 def run(self, installSignalHandlers=True):
#     252     self.startRunning(installSignalHandlers=installSignalHandlers)
# --> 253     self._asyncioEventloop.run_forever()
#     254     if self._justStopped:
#     255         self._justStopped = False
#
# File ~\anaconda3\envs\guvi\Lib\asyncio\base_events.py:597, in BaseEventLoop.run_forever(self)
#     595 """Run until stop() is called."""
#     596 self._check_closed()
# --> 597 self._check_running()
#     598 self._set_coroutine_origin_tracking(self._debug)
#     600 old_agen_hooks = sys.get_asyncgen_hooks()
#
# File ~\anaconda3\envs\guvi\Lib\asyncio\base_events.py:589, in BaseEventLoop._check_running(self)
#     587 def _check_running(self):
#     588     if self.is_running():
# --> 589         raise RuntimeError('This event loop is already running')
#     590     if events._get_running_loop() is not None:
#     591         raise RuntimeError(
#     592             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
# 2025-09-17 14:10:16 [scrapy.core.engine] INFO: Spider opened
# 2025-09-17 14:10:16 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-09-17 14:10:16 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-09-17 14:10:17 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://books.toscrape.com/robots.txt> (referer: None)
# 2025-09-17 14:10:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/> (referer: None)
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'A Light in the Attic', 'price': '£51.77'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Tipping the Velvet', 'price': '£53.74'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Soumission', 'price': '£50.10'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Sharp Objects', 'price': '£47.82'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Sapiens: A Brief History of Humankind', 'price': '£54.23'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Requiem Red', 'price': '£22.65'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'price': '£33.34'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'price': '£17.93'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'price': '£22.60'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'The Black Maria', 'price': '£52.15'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'price': '£13.99'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "Shakespeare's Sonnets", 'price': '£20.66'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Set Me Free', 'price': '£17.46'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'price': '£52.29'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Rip it Up and Start Again', 'price': '£35.02'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'price': '£57.25'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Olio', 'price': '£23.88'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'price': '£37.59'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': 'Libertarianism for Beginners', 'price': '£51.33'}
# 2025-09-17 14:10:18 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/>
# {'title': "It's Only the Himalayas", 'price': '£45.17'}
# 2025-09-17 14:10:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-2.html> (referer: http://books.toscrape.com/)
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'In Her Wake', 'price': '£12.84'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'How Music Works', 'price': '£37.32'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'price': '£30.52'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Chase Me (Paris Nights #2)', 'price': '£25.27'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Black Dust', 'price': '£34.53'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Birdsong: A Story in Pictures', 'price': '£54.64'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'price': '£22.50'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Aladdin and His Wonderful Lamp', 'price': '£53.13'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 'price': '£40.30'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Wall and Piece', 'price': '£44.18'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Four Agreements: A Practical Guide to Personal Freedom', 'price': '£17.66'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'price': '£31.05'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Elephant Tree', 'price': '£23.82'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'The Bear and the Piano', 'price': '£36.89'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "Sophie's World", 'price': '£15.94'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Penny Maybe', 'price': '£33.29'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Maude (1883-1993):She Grew Up with the country', 'price': '£18.02'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'In a Dark, Dark Wood', 'price': '£19.63'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': 'Behind Closed Doors', 'price': '£52.22'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-2.html>
# {'title': "You can't bury them all: Poems", 'price': '£33.63'}
# 2025-09-17 14:10:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-3.html> (referer: http://books.toscrape.com/catalogue/page-2.html)
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Slow States of Collapse: Poems', 'price': '£57.31'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Reasons to Stay Alive', 'price': '£26.41'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Private Paris (Private #10)', 'price': '£47.61'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'price': '£23.11'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Without Borders (Wanderlove #1)', 'price': '£45.07'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'When We Collided', 'price': '£31.77'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'We Love You, Charlie Freeman', 'price': '£50.27'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Untitled Collection: Sabbath Poems 2014', 'price': '£14.27'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 'price': '£44.18'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unicorn Tracks', 'price': '£18.78'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', 'price': '£25.52'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 'price': '£16.28'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity', 'price': '£31.12'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'This One Summer', 'price': '£19.49'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'Thirst', 'price': '£17.27'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Torch Is Passed: A Harding Family Story', 'price': '£19.09'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Secret of Dreadwillow Carse', 'price': '£56.13'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 'price': '£56.41'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Past Never Ends', 'price': '£56.50'}
# 2025-09-17 14:10:20 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-3.html>
# {'title': 'The Natural History of Us (The Fine Art of Pretending #2)', 'price': '£45.22'}
# 2025-09-17 14:10:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-4.html> (referer: http://books.toscrape.com/catalogue/page-3.html)
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Nameless City (The Nameless City #1)', 'price': '£38.16'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Murder That Never Was (Forensic Instincts #5)', 'price': '£54.11'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 'price': '£42.96'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', 'price': '£23.89'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing', 'price': '£16.77'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 'price': '£20.59'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure', 'price': '£37.13'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3', 'price': '£56.06'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Death of Humanity: and the Case for Life', 'price': '£58.11'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 'price': '£49.05'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Art Forger', 'price': '£40.76'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', 'price': '£19.73'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 'price': '£32.24'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 'price': '£41.83'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Soul Reader', 'price': '£39.58'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Security', 'price': '£39.25'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)', 'price': '£25.02'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)', 'price': '£51.04'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Reskilling America: Learning to Labor in the Twenty-First Century', 'price': '£19.83'}
# 2025-09-17 14:10:22 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-4.html>
# {'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', 'price': '£50.40'}
# 2025-09-17 14:10:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-5.html> (referer: http://books.toscrape.com/catalogue/page-4.html)
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 'price': '£13.61'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Princess Between Worlds (Wide-Awake Princess #5)', 'price': '£13.34'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Pop Gun War, Volume 1: Gift', 'price': '£18.97'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 'price': '£36.28'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Patience', 'price': '£10.16'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 'price': '£15.44'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)', 'price': '£48.41'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide', 'price': '£46.35'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'On a Midnight Clear', 'price': '£14.07'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Obsidian (Lux #1)', 'price': '£14.86'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'My Paris Kitchen: Recipes and Stories', 'price': '£33.37'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Masks and Shadows', 'price': '£56.40'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 'price': '£14.02'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 'price': '£46.91'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', 'price': '£45.61'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 'price': '£19.92'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Layered: Baking, Building, and Styling Spectacular Cakes', 'price': '£40.11'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 'price': '£53.90'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'Join', 'price': '£35.67'}
# 2025-09-17 14:10:23 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-5.html>
# {'title': 'In the Country We Love: My Family Divided', 'price': '£22.00'}
# 2025-09-17 14:10:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-6.html> (referer: http://books.toscrape.com/catalogue/page-5.html)
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 'price': '£57.36'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)', 'price': '£29.17'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'I am a Hero Omnibus Volume 1', 'price': '£54.63'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'How to Be Miserable: 40 Strategies You Already Use', 'price': '£46.03'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Her Backup Boyfriend (The Sorensen Family #1)', 'price': '£33.97'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Giant Days, Vol. 2 (Giant Days #5-8)', 'price': '£22.11'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton', 'price': '£29.69'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'First and First (Five Boroughs #3)', 'price': '£15.97'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Fifty Shades Darker (Fifty Shades #2)', 'price': '£21.96'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day', 'price': '£54.35'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", 'price': '£37.97'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Danganronpa Volume 1', 'price': '£51.99'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Crown of Midnight (Throne of Glass #2)', 'price': '£43.29'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Codename Baboushka, Volume 1: The Conclave of Death', 'price': '£36.72'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Camp Midnight', 'price': '£17.08'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 'price': '£29.14'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Burning', 'price': '£28.81'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Bossypants', 'price': '£49.46'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))', 'price': '£37.92'}
# 2025-09-17 14:10:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-6.html>
# {'title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)', 'price': '£28.09'}
# 2025-09-17 14:10:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://books.toscrape.com/catalogue/page-7.html> (referer: http://books.toscrape.com/catalogue/page-6.html)
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Algorithms to Live By: The Computer Science of Human Decisions', 'price': '£30.81'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A World of Flavor: Your Gluten Free Passport', 'price': '£42.95'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 'price': '£56.76'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Murder in Time', 'price': '£16.64'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Flight of Arrows (The Pathfinders #2)', 'price': '£55.53'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Fierce and Subtle Poison', 'price': '£28.13'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)', 'price': '£52.37'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': '(Un)Qualified: How God Uses Broken People to Do Big Things', 'price': '£54.00'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'You Are What You Love: The Spiritual Power of Habit', 'price': '£21.87'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", 'price': '£43.30'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Tuesday Nights in 1980', 'price': '£21.04'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Tracing Numbers on a Train', 'price': '£41.60'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Throne of Glass (Throne of Glass #1)', 'price': '£35.07'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', 'price': '£59.64'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'Thirteen Reasons Why', 'price': '£52.72'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”', 'price': '£58.08'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Wedding Dress', 'price': '£24.12'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Vacationers', 'price': '£42.15'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Third Wave: An Entrepreneur’s Vision of the Future', 'price': '£12.61'}
# 2025-09-17 14:10:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://books.toscrape.com/catalogue/page-7.html>
# {'title': 'The Stranger', 'price': '£17.44'}
